# %% [markdown]
# | **Author**          | **Roll No**   | **Version** |
# |---------------------|----------------|--------------|
# | Vinayak Rana        | 24210114       | 1.0          |
#
# #### Introduction
# Welcome to this Jupyter Notebook! In this notebook, we will scrap data from arxiv.

# %%
import requests
from bs4 import BeautifulSoup

# %%
def scrap_page(url,default_name):
    response = requests.get(url)
    if response.status_code == 200:
        page = BeautifulSoup(response.content,'html.parser')
        tags = page.find_all('p')

        file_name = page.find('h1').get_text().strip()+'.txt'
        if not file_name:
            file_name = default_name

        # file_path = 'Data/arxiv_data/'+file_name
        # with open(file_path,'w',encoding='utf-8') as f:
        #     for p in tags:
        #         f.write(p.get_text()+'\n')
        # print(f'File saved for {file_name}')

# %%
def expand_page(url):
    response = requests.get(url)
    page=BeautifulSoup(response.content,'html.parser')
    temp=page.find_all(class_='morefewer')
    return 'https://arxiv.org/'+temp[0].find_all('a')[-1]['href']

# %%
response=requests.get('https://arxiv.org/')
page=BeautifulSoup(response.content,'html.parser')
content = page.find('div',id='content')
li=content.find_all('li')

# %%
links=[]

response=requests.get('https://arxiv.org/')
page=BeautifulSoup(response.content,'html.parser')
content = page.find('div',id='content')
li=content.find_all('li')

a_tags = li[14].find_all('a')[5:]
for a in a_tags:
    href = 'https://arxiv.org/'+a['href']

    try:
        expanded_page_link = expand_page(href)
    except:
        continue
    
    response = requests.get(expanded_page_link)
    expanded_page = BeautifulSoup(response.content,'html.parser')

    dt_tags = expanded_page.find_all('dt')
    
    for i,dt in enumerate(dt_tags):
        link = dt.find_all('a')[3]['href']
        
        default_name = 'default_file'+str(i)

        try:
            scrap_page(link,default_name)
            links.append(link)
        except:
            print(f'Failure for link {link}')
# Out:
# Failure for link /format/2409.08642
# Failure for link /format/2409.09001
# Failure for link /format/2409.08798
# Failure for link /format/2409.08761
# Failure for link https://arxiv.org/html/2409.08703v1
# Failure for link /format/2409.08603
# Failure for link /format/2409.08602
# Failure for link /format/2409.08483
# Failure for link /format/2409.08479
# Failure for link /format/2409.08379
# Failure for link /format/2409.08297
# Failure for link /format/2409.07507
# Failure for link /format/2409.07930
# Failure for link /format/2409.07918
# Failure for link /format/2409.07684
# Failure for link /format/2409.07672
# Failure for link https://arxiv.org/html/2409.07629v1
# Failure for link /format/2409.07493
# Failure for link /format/2409.07476
# Failure for link /format/2409.07469
# Failure for link https://arxiv.org/html/2409.07415v1
# Failure for link /format/2409.07314
# Failure for link /format/2409.07151
# Failure for link /format/2409.07033
# Failure for link /format/2409.06978
# Failure for link /format/2409.06805
# Failure for link /format/2409.06800
# Failure for link /format/2409.06756
# Failure for link /format/2409.06729
# Failure for link /format/2409.06723
# Failure for link /format/2409.06721
# Failure for link /format/2409.06691
# Failure for link /format/2409.06644
# Failure for link /format/2409.06468
# Failure for link /format/2409.06096
# Failure for link /format/2409.05907
# Failure for link /format/2409.05888
# Failure for link /format/2409.05556
# Failure for link /format/2409.05808
# Failure for link /format/2409.05672
# Failure for link /format/2409.05564
# Failure for link /format/2409.05358
# Failure for link /format/2409.05292
# Failure for link /format/2409.05277
# Failure for link https://arxiv.org/html/2409.05265v1
# Failure for link /format/2409.05197
# Failure for link /format/2409.05152
# Failure for link /format/2409.04977
# Failure for link /format/2409.04915
# Failure for link /format/2409.04840
# Failure for link https://arxiv.org/html/2409.04740v1
# Failure for link /format/2409.04707
# Failure for link /format/2409.04631
# Failure for link /format/2409.04615
# Failure for link /format/2409.04600
# Failure for link /format/2409.04576
# Failure for link /format/2409.04464
# Failure for link https://arxiv.org/html/2409.04456v1
# Failure for link /format/2409.09001
# Failure for link /format/2409.08792
# Failure for link /format/2409.08523
# Failure for link /format/2409.08483
# Failure for link /format/2409.08963
# Failure for link /format/2409.08761
# Failure for link /format/2409.07672
# Failure for link /format/2409.07839
# Failure for link /format/2409.07476
# Failure for link /format/2409.07314
# Failure for link /format/2409.06857
# Failure for link /format/2409.06550
# Failure for link /format/2409.06468
# Failure for link /format/2409.06043
# Failure for link /format/2409.05977
# Failure for link /format/2409.06691
# Failure for link /format/2409.06226
# Failure for link /format/2409.06033
# Failure for link /format/2409.05907
# Failure for link /format/2409.05448
# Failure for link /format/2409.05197
# Failure for link /format/2409.05152
# Failure for link /format/2409.05136
# Failure for link /format/2409.05134
# Failure for link /format/2409.04464
# Failure for link /format/2409.05556
# Failure for link /format/2409.05292
# Failure for link /format/2409.04507
# Failure for link /format/2409.08761
# Failure for link /format/2409.07626
# Failure for link /format/2409.07035
# Failure for link /format/2409.06977
# Failure for link /format/2409.06967
# Failure for link /format/2409.06120
# Failure for link /format/2409.06025
# Failure for link /format/2409.05046
# Failure for link /format/2409.04592
# Failure for link /format/2409.08285
# Failure for link /format/2409.08136
# Failure for link /format/2409.07551
# Failure for link https://arxiv.org/html/2409.06727v1
# Failure for link /format/2409.06725
# Failure for link /format/2409.05778
# Failure for link /format/2409.05478
# Failure for link /format/2409.05365
# Failure for link https://arxiv.org/html/2409.04740v1
# Failure for link /format/2409.04462
# Failure for link /format/2409.08227
# Failure for link /format/2409.08502
# Failure for link /format/2409.08491
# Failure for link https://arxiv.org/html/2409.08495v1
# Failure for link https://arxiv.org/html/2409.07398v1
# Failure for link /format/2409.07142
# Failure for link /format/2409.06971
# Failure for link /format/2409.06157
# Failure for link /format/2409.06184
# Failure for link https://arxiv.org/html/2409.04914v1
# Failure for link /format/2409.08847
# Failure for link /format/2409.08508
# Failure for link /format/2409.08283
# Failure for link /format/2409.08619
# Failure for link /format/2409.08618
# Failure for link /format/2409.08588
# Failure for link /format/2409.08474
# Failure for link /format/2409.08277
# Failure for link /format/2409.08251
# Failure for link /format/2409.08181
# Failure for link /format/2409.08171
# Failure for link https://arxiv.org/html/2409.08156v1
# Failure for link /format/2409.08026
# Failure for link https://arxiv.org/html/2409.07752v1
# Failure for link /format/2409.07577
# Failure for link /format/2409.07566
# Failure for link /format/2409.07469
# Failure for link https://arxiv.org/html/2409.08163v1
# Failure for link /format/2409.08130
# Failure for link /format/2409.07759
# Failure for link /format/2409.07493
# Failure for link /format/2409.07295
# Failure for link /format/2409.06942
# Failure for link https://arxiv.org/html/2409.06815v1
# Failure for link /format/2409.06705
# Failure for link /format/2409.07422
# Failure for link /format/2409.07379
# Failure for link /format/2409.07253
# Failure for link /format/2409.06671
# Failure for link /format/2409.06644
# Failure for link /format/2409.06633
# Failure for link /format/2409.06609
# Failure for link https://arxiv.org/html/2409.06443v1
# Failure for link /format/2409.06407
# Failure for link /format/2409.06235
# Failure for link /format/2409.05985
# Failure for link /format/2409.06699
# Failure for link /format/2409.06689
# Failure for link /format/2409.06687
# Failure for link /format/2409.06030
# Failure for link https://arxiv.org/html/2409.05817v1
# Failure for link /format/2409.05679
# Failure for link /format/2409.05564
# Failure for link /format/2409.05540
# Failure for link /format/2409.05389
# Failure for link /format/2409.05277
# Failure for link /format/2409.05225
# Failure for link /format/2409.05174
# Failure for link /format/2409.05089
# Failure for link /format/2409.04915
# Failure for link /format/2409.04825
# Failure for link /format/2409.04750
# Failure for link /format/2409.04563
# Failure for link /format/2409.05680
# Failure for link /format/2409.05666
# Failure for link /format/2409.05255
# Failure for link /format/2409.04977
# Failure for link /format/2409.04631
# Failure for link /format/2409.04615
# Failure for link https://arxiv.org/html/2409.04456v1
# Failure for link /format/2409.08963
# Failure for link /format/2409.08284
# Failure for link /format/2409.09001
# Failure for link /format/2409.08952
# Failure for link /format/2409.07878
# Failure for link /format/2409.07611
# Failure for link /format/2409.07476
# Failure for link /format/2409.07475
# Failure for link /format/2409.07470
# Failure for link /format/2409.06730
# Failure for link /format/2409.06729
# Failure for link /format/2409.06723
# Failure for link /format/2409.06721
# Failure for link /format/2409.05876
# Failure for link /format/2409.05082
# Failure for link /format/2409.05292
# Failure for link /format/2409.04794
# Failure for link /format/2409.08952
# Failure for link https://arxiv.org/html/2409.08774v1
# Failure for link /format/2409.08529
# Failure for link /format/2409.08476
# Failure for link /format/2409.08390
# Failure for link /format/2409.08786
# Failure for link https://arxiv.org/html/2409.07508v1
# Failure for link /format/2409.07863
# Failure for link https://arxiv.org/html/2409.07415v1
# Failure for link /format/2409.07167
# Failure for link /format/2409.07138
# Failure for link https://arxiv.org/html/2409.06816v2
# Failure for link /format/2409.06805
# Failure for link /format/2409.06128
# Failure for link /format/2409.06317
# Failure for link https://arxiv.org/html/2409.04474v1
# Failure for link /format/2409.08227
# Failure for link https://arxiv.org/html/2409.06453v1
# Failure for link /format/2409.06199
# Failure for link /format/2409.06034
# Failure for link /format/2409.08284
# Failure for link /format/2409.08142
# Failure for link /format/2409.06936
# Failure for link /format/2409.08897
# Failure for link /format/2409.08473
# Failure for link /format/2409.09001
# Failure for link /format/2409.06852
# Failure for link /format/2409.06936
# Failure for link /format/2409.05899
# Failure for link /format/2409.04600
# Failure for link /format/2409.06968
# Failure for link /format/2409.06755
# Failure for link /format/2409.08949
# Failure for link /format/2409.07734
# Failure for link /format/2409.07693
# Failure for link https://arxiv.org/html/2409.08108v1
# Failure for link /format/2409.07903
# Failure for link /format/2409.06066
# Failure for link /format/2409.05768
# Failure for link /format/2409.08416
# Failure for link /format/2409.08055
# Failure for link /format/2409.05759
# Failure for link /format/2409.05055
# Failure for link /format/2409.07882
# Failure for link /format/2409.06978
# Failure for link /format/2409.06977
# Failure for link /format/2409.06976
# Failure for link /format/2409.06975
# Failure for link /format/2409.06974
# Failure for link /format/2409.06973
# Failure for link /format/2409.06972
# Failure for link /format/2409.07148
# Failure for link /format/2409.06030
# Failure for link /format/2409.04507
# Failure for link /format/2409.08286
# Failure for link /format/2409.08949
# Failure for link /format/2409.07903
# Failure for link /format/2409.08798
# Failure for link /format/2409.08963
# Failure for link /format/2409.08226
# Failure for link /format/2409.07918
# Failure for link /format/2409.07765
# Failure for link https://arxiv.org/html/2409.07696v1
# Failure for link https://arxiv.org/html/2409.07695v1
# Failure for link /format/2409.07484
# Failure for link /format/2409.07475
# Failure for link https://arxiv.org/html/2409.07444v2
# Failure for link /format/2409.06725
# Failure for link /format/2409.06643
# Failure for link /format/2409.06354
# Failure for link /format/2409.06011
# Failure for link /format/2409.05876
# Failure for link /format/2409.05703
# Failure for link /format/2409.05496
# Failure for link /format/2409.05176
# Failure for link /format/2409.04987
# Failure for link https://arxiv.org/html/2409.05817v1
# Failure for link https://arxiv.org/html/2409.08703v1
# Failure for link /format/2409.08479
# Failure for link /format/2409.07033
# Failure for link /format/2409.06638
# Failure for link /format/2409.06150
# Failure for link /format/2409.06096
# Failure for link /format/2409.05152
# Failure for link /format/2409.08786
# Failure for link /format/2409.08462
# Failure for link /format/2409.05619
# Failure for link /format/2409.04507
# Failure for link /format/2409.06966
# Failure for link /format/2409.06634
# Failure for link /format/2409.08861
# Failure for link /format/2409.08760
# Failure for link /format/2409.08752
# Failure for link /format/2409.08676
# Failure for link /format/2409.08660
# Failure for link /format/2409.08558
# Failure for link /format/2409.08474
# Failure for link https://arxiv.org/html/2409.08954v1
# Failure for link /format/2409.08847
# Failure for link /format/2409.08786
# Failure for link /format/2409.08642
# Failure for link https://arxiv.org/html/2409.08426v1
# Failure for link https://arxiv.org/html/2409.08395v1
# Failure for link /format/2409.08311
# Failure for link /format/2409.08309
# Failure for link /format/2409.08297
# Failure for link /format/2409.08283
# Failure for link https://arxiv.org/html/2409.08163v1
# Failure for link https://arxiv.org/html/2409.08105v1
# Failure for link /format/2409.08036
# Failure for link /format/2409.08020
# Failure for link /format/2409.07997
# Failure for link /format/2409.07853
# Failure for link /format/2409.07839
# Failure for link /format/2409.07734
# Failure for link /format/2409.07626
# Failure for link /format/2409.07577
# Failure for link /format/2409.07507
# Failure for link /format/2409.07493
# Failure for link /format/2409.07484
# Failure for link /format/2012.01349
# Failure for link /format/2409.07379
# Failure for link /format/2409.07253
# Failure for link https://arxiv.org/html/2409.06830v1
# Failure for link /format/2409.06805
# Failure for link /format/2409.06800
# Failure for link /format/2409.06756
# Failure for link /format/2409.07434
# Failure for link https://arxiv.org/html/2409.07415v1
# Failure for link /format/2409.07347
# Failure for link /format/2409.07326
# Failure for link /format/2409.07032
# Failure for link /format/2409.06890
# Failure for link /format/2409.06735
# Failure for link /format/2409.06730
# Failure for link /format/2409.06728
# Failure for link /format/2409.06725
# Failure for link /format/2409.06691
# Failure for link /format/2409.06085
# Failure for link /format/2409.05928
# Failure for link /format/2409.05918
# Failure for link /format/2409.05907
# Failure for link /format/2409.06609
# Failure for link /format/2409.06407
# Failure for link /format/2409.06271
# Failure for link /format/2409.06235
# Failure for link /format/2409.06226
# Failure for link /format/2409.06157
# Failure for link /format/2409.06080
# Failure for link /format/2409.05804
# Failure for link /format/2409.05672
# Failure for link /format/2409.05513
# Failure for link /format/2409.05358
# Failure for link /format/2409.05292
# Failure for link https://arxiv.org/html/2409.05265v1
# Failure for link /format/2409.04977
# Failure for link /format/2409.04860
# Failure for link /format/2409.04840
# Failure for link /format/2409.04794
# Failure for link https://arxiv.org/html/2409.04740v1
# Failure for link /format/2409.04707
# Failure for link /format/2409.05778
# Failure for link /format/2409.05577
# Failure for link /format/2409.05556
# Failure for link /format/2409.05389
# Failure for link https://arxiv.org/html/2409.05354v1
# Failure for link /format/2409.05255
# Failure for link /format/2409.05181
# Failure for link /format/2409.05152
# Failure for link /format/2409.05023
# Failure for link /format/2409.04915
# Failure for link /format/2409.04708
# Failure for link https://arxiv.org/html/2409.04597v1
# Failure for link /format/2409.04491
# Failure for link /format/2409.04464
# Failure for link https://arxiv.org/html/2409.04456v1
# Failure for link /format/2409.06085
# Failure for link https://arxiv.org/html/2409.08404v1
# Failure for link /format/2409.07759
# Failure for link /format/2409.06207
# Failure for link /format/2409.05540
# Failure for link /format/2409.05496
# Failure for link /format/2409.08416
# Failure for link /format/2409.07994
# Failure for link https://arxiv.org/html/2409.07444v2
# Failure for link /format/2409.06207
# Failure for link /format/2409.06098
# Failure for link /format/2409.05904
# Failure for link /format/2409.05888
# Failure for link /format/2409.05264
# Failure for link /format/2409.07833
# Failure for link https://arxiv.org/html/2409.08401v1
# Failure for link /format/2409.07605
# Failure for link https://arxiv.org/html/2409.06988v1
# Failure for link https://arxiv.org/html/2409.07111v1
# Failure for link /format/2409.07084
# Failure for link /format/2409.06045
# Failure for link /format/2409.06184
# Failure for link /format/2409.06085
# Failure for link /format/2409.05791
# Failure for link /format/2409.05479
# Failure for link /format/2409.05231
# Failure for link /format/2409.04708
# Failure for link /format/2409.05706
# Failure for link https://arxiv.org/html/2409.07508v1
# Failure for link https://arxiv.org/html/2409.08108v1
# Failure for link /format/2409.07360
# Failure for link /format/2409.06505
# Failure for link https://arxiv.org/html/2409.04597v1
# Failure for link /format/2409.08889
# Failure for link https://arxiv.org/html/2409.08420v1
# Failure for link /format/2409.08414
# Failure for link /format/2409.08337
# Failure for link /format/2409.08825
# Failure for link /format/2409.07228
# Failure for link /format/2409.07160
# Failure for link /format/2409.07050
# Failure for link /format/2409.07013
# Failure for link /format/2409.06503
# Failure for link /format/2409.06419
# Failure for link /format/2409.06395
# Failure for link /format/2409.05196
# Failure for link /format/2409.05029
# Failure for link /format/2409.04785
# Failure for link /format/2409.04576
# Failure for link /format/2409.04558
# Failure for link /format/2409.05564
# Failure for link /format/2409.08298
# Failure for link /format/2409.07720
# Failure for link /format/2409.07684
# Failure for link /format/2409.05292
# Failure for link /format/2409.04860
# Failure for link /format/2409.08379
# Failure for link https://arxiv.org/html/2409.07629v1
# Failure for link /format/2409.07360
# Failure for link /format/2409.07228
# Failure for link /format/2409.06268
# Failure for link /format/2409.06264
# Failure for link /format/2409.06176
# Failure for link /format/2409.05808
# Failure for link /format/2409.05055
# Failure for link /format/2409.05019
# Failure for link https://arxiv.org/html/2409.04597v1
# Failure for link https://arxiv.org/html/2409.04474v1
# Failure for link https://arxiv.org/html/2409.08731v1
# Failure for link /format/2409.08618
# Failure for link /format/2409.08605
# Failure for link /format/2409.08309
# Failure for link /format/2409.07918
# Failure for link https://arxiv.org/html/2409.06451v1
# Failure for link /format/2409.06395
# Failure for link /format/2409.06096
# Failure for link /format/2409.06033
# Failure for link /format/2409.06468
# Failure for link /format/2409.08825
# Failure for link https://arxiv.org/html/2409.08576v1
# Failure for link https://arxiv.org/html/2409.08300v1
# Failure for link /format/2409.08638
# Failure for link /format/2409.07933
# Failure for link /format/2409.07785
# Failure for link /format/2409.07598
# Failure for link /format/2409.07254
# Failure for link https://arxiv.org/html/2409.06828v1
# Failure for link /format/2409.06194
# Failure for link /format/2409.05904
# Failure for link /format/2101.08160
# Failure for link /format/2409.05132
# Failure for link https://arxiv.org/html/2409.05044v1
# Failure for link /format/2409.04462
# Failure for link /format/2409.04446
# Failure for link /format/2409.05029

# %%
with open('Data/arxiv_data/links.txt','w') as f:
    for item in links:
        f.write(item+'\n')

# %%
import os

# %%
len(os.listdir('Data/arxiv_data'))
# Out:
# 2029

# %%
file_size = os.path.getsize('Data/arxiv_data')

# %%
total_size=0
for item in os.listdir('Data/arxiv_data'):
    total_size+=os.path.getsize('Data/arxiv_data/'+item)

# %%
len(links)
# Out:
# 2948
