# %% [markdown]
# | **Author**          | **Roll No**   | **Version** |
# |---------------------|----------------|--------------|
# | Vinayak Rana        | 24210114       | 1.0          |
#
# #### Introduction
# In this notebook we will scrap lecture transcripts from Nptel official website (https://nptel.ac.in/courses).

# %%
import requests
import pdfplumber
import os

# %%
def download_file_from_google_drive(file_id, destination='Data/Nptel_data/pdfs'):

    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"
    response = requests.get(download_url)
    
    if response.status_code == 200:
        with open(destination, 'wb') as file:
            file.write(response.content)
        print(f"File downloaded successfully: {destination}")
    else:
        print(f'Failure for link {download_url}')

def extract_text_with_pdfplumber(pdf_file):
    with pdfplumber.open(pdf_file) as pdf:
        text = ""
        for page in pdf.pages:
            text += page.extract_text()
        return text

# %%
def download_book(file_id, destination_folder, file_name):
 
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"
    
    response = requests.get(download_url)
    if response.status_code == 200:
        destination = os.path.join(destination_folder, f"{file_name}.pdf")
        
        with open(destination, 'wb') as file:
            file.write(response.content)
        
        print(f"File downloaded successfully: {destination}")
        return destination 
    else:
        print(f"Failed to download file from {download_url}")
        return None

def extract_text(pdf_file):
    try:
        with pdfplumber.open(pdf_file) as pdf:
            text = ""
            for page in pdf.pages:
                text += page.extract_text()
            return text
    except:
        print('Corrupt or wrong pdf')
        return ""

def book_scrap(file_ids, destination_folder='Data/Nptel_data/'):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    
    for i, file_id in enumerate(file_ids):
        file_name = str(i+1004)
        
        pdf_path = download_book(file_id, destination_folder+'Pdfs', file_name)
        
        if pdf_path:
            extracted_text = extract_text(pdf_path)
            
            txt_file_path = os.path.join(destination_folder+'Pdf text', f"{file_name}.txt")
            with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
                txt_file.write(extracted_text)
            
            print(f"Text extracted and saved to: {txt_file_path}")

# %%
def find_id():
    file_id = []
    with open('Data/Nptel_data/links.txt','r') as f:
        for line in f:
            link = line.strip()
            if link:
                file_id.append(link[32:-5])
    return file_id

# %%
file_ids = find_id()

# %%
book_scrap(file_ids[1004:])
# Out:
# File downloaded successfully: Data/Nptel_data/Pdfs/1004.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1004.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1005.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1005.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1006.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1006.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1007.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1007.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1008.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1008.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1009.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1009.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1010.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1010.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1011.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1011.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1012.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1012.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1013.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1013.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1014.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1014.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1015.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1015.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1016.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1016.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1017.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1017.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1018.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1018.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1019.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1019.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1020.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1020.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1021.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1021.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1022.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1022.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1023.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1023.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1024.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1024.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1025.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1025.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1026.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1026.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1027.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1027.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1028.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1028.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1029.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1029.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1030.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1030.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1031.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1031.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1032.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1032.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1033.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1033.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1034.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1034.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1035.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1035.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1036.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1036.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1037.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1037.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1038.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1038.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1039.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1039.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1040.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1040.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1041.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1041.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1042.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1042.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1043.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1043.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1044.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1044.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1045.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1045.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1046.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1046.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1047.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1047.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1048.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1048.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1049.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1049.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1050.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1050.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1051.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1051.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1052.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1052.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1053.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1053.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1054.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1054.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1055.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1055.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1056.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1056.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1057.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1057.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1058.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1058.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1059.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1059.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1060.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1060.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1061.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1061.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1062.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1062.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1063.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1063.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1064.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1064.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1065.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1065.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1066.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1066.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1067.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1067.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1068.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1068.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1069.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1069.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1070.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1070.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1071.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1071.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1072.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1072.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1073.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1073.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1074.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1074.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1075.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1075.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1076.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1076.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1077.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1077.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1078.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1078.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1079.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1079.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1080.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1080.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1081.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1081.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1082.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1082.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1083.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1083.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1084.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1084.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1085.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1085.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1086.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1086.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1087.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1087.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1088.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1088.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1089.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1089.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1090.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1090.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1091.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1091.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1092.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1092.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1093.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1093.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1094.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1094.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1095.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1095.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1096.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1096.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1097.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1097.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1098.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1098.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1099.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1099.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1100.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1100.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1101.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1101.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1102.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1102.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1103.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1103.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1104.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1104.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1105.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1105.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1106.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1106.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1107.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1107.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1108.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1108.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1109.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1109.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1110.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1110.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1111.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1111.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1112.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1112.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1113.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1113.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1114.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1114.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1115.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1115.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1116.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1116.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1117.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1117.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1118.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1118.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1119.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1119.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1120.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1120.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1121.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1121.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1122.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1122.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1123.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1123.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1124.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1124.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1125.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1125.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1126.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1126.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1127.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1127.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1128.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1128.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1129.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1129.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1130.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1130.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1131.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1131.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1132.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1132.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1133.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1133.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1134.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1134.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1135.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1135.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1136.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1136.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1137.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1137.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1138.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1138.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1139.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1139.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1140.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1140.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1141.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1141.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1142.pdf
# Corrupt or wrong pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1142.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1143.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1143.txt
# File downloaded successfully: Data/Nptel_data/Pdfs/1144.pdf
# Text extracted and saved to: Data/Nptel_data/Pdf text/1144.txt

# %%
372,373,374
# Out:
# (372, 373, 374)
