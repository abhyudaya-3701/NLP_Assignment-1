# %% [markdown]
# | **Author**          | **Roll No**   | **Version** |
# |---------------------|----------------|--------------|
# | Abhyudaya Nair      | 24210005      | 1.0          |

# %% [markdown]
# ### Link Crawling

# %%
import requests
from bs4 import BeautifulSoup
import csv
import os
from urllib.parse import urljoin, urlparse

# Define the base URL
base_url = "https://publicdomainreview.org/"

# Define the file to store article links
csv_file = 'Abhyudaya/Scripts and Data/pdr_article_links.csv'
progress_file = 'Abhyudaya/Scripts and Data/pdr_links_to_traverse.txt'  # File to store progress

# Store visited links to avoid reprocessing and duplicates
visited_links = set()
links_to_traverse = []  # Initialize as empty list
article_links = set()  # To store unique article links

# Write the article link to CSV
def save_article_link(link):
    with open(csv_file, 'a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([link])

# Function to fetch and parse the HTML content
def get_html_content(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        response.encoding = response.apparent_encoding  # Set encoding based on response
        return response.content  # Return raw content for parsing
    except requests.exceptions.RequestException as e:
        print(f"Failed to retrieve {url}: {e}")
        return None

# Extracts all unique links from a given page, ignoring those with "#"
def extract_links(soup, base_url):
    links = set()
    for anchor in soup.find_all('a', href=True):
        href = anchor['href']
        full_url = urljoin(base_url, href)  # Construct full URL

        # Ignore links that contain "#"
        if "#" in full_url:
            continue

        # Ensure the link belongs to publicdomainreview.org and is a valid HTTP link
        if "publicdomainreview.org" in urlparse(full_url).netloc and full_url.startswith("http"):
            links.add(full_url)
    return links

# Process the current URL and extract new links
def process_link(url):
    raw_html = get_html_content(url)
    if raw_html is None:
        return

    try:
        soup = BeautifulSoup(raw_html, 'html.parser')  # Attempt to parse HTML
    except Exception as e:
        print(f"Parsing error for {url}: {e}")
        return  # Skip this link and continue

    # Extract all unique links from the current page
    links = extract_links(soup, url)

    # Filter and save article links that start with "https://publicdomainreview.org"
    for link in links:
        if link.startswith("https://publicdomainreview.org") and link not in article_links:
            article_links.add(link)
            save_article_link(link)
            print(f"Saved article link: {link}")

    # Add unvisited links to the links_to_traverse list
    for link in links:
        if link not in visited_links:
            links_to_traverse.append(link)

# Load previously saved links from the progress file
def load_progress():
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as file:
            return [line.strip() for line in file.readlines()]
    return []

# Save the current state of links_to_traverse to the progress file
def save_progress():
    with open(progress_file, 'w') as file:
        for link in links_to_traverse:
            file.write(link + '\n')

# Main crawling loop
links_to_traverse = load_progress() or [base_url]  # Load progress or start fresh

while links_to_traverse:
    current_link = links_to_traverse.pop(0)
    if current_link not in visited_links:
        print(f"Processing: {current_link}")
        visited_links.add(current_link)
        process_link(current_link)
        
        # Save progress after processing each link
        save_progress()

# Final save of progress when done
save_progress()
print("Crawling complete. Progress saved.")
# Out:
# Processing: https://publicdomainreview.org/
# Saved article link: https://publicdomainreview.org/blog/
# Saved article link: https://publicdomainreview.org/support/
# Saved article link: https://publicdomainreview.org/collection/eluard-ernst-les-malheurs-des-immortels/
# Saved article link: https://publicdomainreview.org/essay/scenes-of-reading-on-the-early-portrait-postcard/
# Saved article link: https://publicdomainreview.org/contact/
# Saved article link: https://publicdomainreview.org/collection/principles-of-light-and-color/
# Saved article link: https://publicdomainreview.org/returns-policy/
# Saved article link: https://publicdomainreview.org/essays/category/art-and-illustration/
# Saved article link: https://publicdomainreview.org/about/
# Saved article link: https://publicdomainreview.org/reusing-material/
# Saved article link: https://publicdomainreview.org/collections/all/theme/travel-and-exploration/
# Saved article link: https://publicdomainreview.org/collections/all/theme/science-and-medicine/
# Saved article link: https://publicdomainreview.org/explore/
# Saved article link: https://publicdomainreview.org/essays/category/photography/
# Saved article link: https://publicdomainreview.org/essay/henri-rochefort-and-the-origins-of-french-populism/
# Saved article link: https://publicdomainreview.org/collection/briefe-and-true-report-de-bry-engravings/
# Saved article link: https://publicdomainreview.org/collections/
# Saved article link: https://publicdomainreview.org/collections/all/theme/colonialism-and-the-'other'/
# Saved article link: https://publicdomainreview.org/shop/
# Saved article link: https://publicdomainreview.org/about/submissions/
# Saved article link: https://publicdomainreview.org/
# Saved article link: https://publicdomainreview.org/collections/books/
# Saved article link: https://publicdomainreview.org/support/friends/
# Saved article link: https://publicdomainreview.org/shop/pdr-press-books/
# Saved article link: https://publicdomainreview.org/collections/all/theme/people/
# Saved article link: https://publicdomainreview.org/collections/all/theme/politics/
# Saved article link: https://publicdomainreview.org/collection/cardiff-giant/
# Saved article link: https://publicdomainreview.org/terms-and-conditions/
# Saved article link: https://publicdomainreview.org/collections/all/theme/customs-and-culture/
# Saved article link: https://publicdomainreview.org/series/curators-choice/
# Saved article link: https://publicdomainreview.org/terms-and-conditions
# Saved article link: https://publicdomainreview.org/essay/our-mortal-waltz-the-dance-of-death-across-centuries/
# Saved article link: https://publicdomainreview.org/shop/delivery-estimates
# Saved article link: https://publicdomainreview.org/explore/indexed/
# Saved article link: https://publicdomainreview.org/collections/all/theme/music-and-arts/
# Saved article link: https://publicdomainreview.org/essay/mimesis-expression-construction/
# Saved article link: https://publicdomainreview.org/collections/all/theme/animals-and-beasts/
# Saved article link: https://publicdomainreview.org/series/conjectures/
# Saved article link: https://publicdomainreview.org/collection/victoria-woodhull-the-impending-revolution/
# Saved article link: https://publicdomainreview.org/essays/category/culture-and-history/
# Saved article link: https://publicdomainreview.org/about/masthead/
# Saved article link: https://publicdomainreview.org/collections/all/theme/strange-phenomena/
# Saved article link: https://publicdomainreview.org/essay/wordsworth-donisthorpe-blackmail-and-the-first-motion-pictures/
# Saved article link: https://publicdomainreview.org/subscribe/
# Saved article link: https://publicdomainreview.org/privacy-policy/
# Saved article link: https://publicdomainreview.org/rights-labelling-on-our-site/
# Saved article link: https://publicdomainreview.org/shop-faq/
# Saved article link: https://publicdomainreview.org/essays/
# Saved article link: https://publicdomainreview.org/collections/images/
# Saved article link: https://publicdomainreview.org/what-is-the-public-domain/
# Saved article link: https://publicdomainreview.org/essays/category/film/
# Saved article link: https://publicdomainreview.org/collection/tardigrade/
# Saved article link: https://publicdomainreview.org/collections/all/theme/food/
# Saved article link: https://publicdomainreview.org/sources/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/
# Saved article link: https://publicdomainreview.org/collections/all/theme/design-and-typography/
# Saved article link: https://publicdomainreview.org/collection/yellow-silence-miniature-from-the-silos-apocalypse/
# Saved article link: https://publicdomainreview.org/essay/gottfried-mind-the-raphael-of-cats/
# Saved article link: https://publicdomainreview.org/collections/all/theme/religion-myth-and-legend/
# Saved article link: https://publicdomainreview.org/further-reading/
# Saved article link: https://publicdomainreview.org/collection/cornaro-sure-and-certain-methods/
# Processing: https://publicdomainreview.org/blog/
# Saved article link: https://publicdomainreview.org/blog/2023/01/introducing-pdr-revisited/
# Saved article link: https://publicdomainreview.org/blog/2020/04/zoom-backgrounds/
# Saved article link: https://publicdomainreview.org/blog/2022/11/last-order-dates-for-christmas-2022/
# Saved article link: https://publicdomainreview.org/blog/2020/03/free-colouring-book/
# Saved article link: https://publicdomainreview.org/blog/2022/06/launch-of-mid-year-fundraiser-june-22/
# Saved article link: https://publicdomainreview.org/blog/2022/04/affinities-trade-edition-available-for-pre-order/
# Saved article link: https://publicdomainreview.org/blog/2021/12/all-sound-recordings-prior-to-1923-will-enter-the-us-public-domain-in-2022/
# Saved article link: https://publicdomainreview.org/blog/2023/06/launch-of-mid-year-fundraiser-june-23/
# Saved article link: https://publicdomainreview.org/blog/2020/08/work-with-the-public-domain-review/
# Saved article link: https://publicdomainreview.org/blog/2024/01/public-domain-day-2024/
# Saved article link: https://publicdomainreview.org/blog/2022/01/public-domain-day-2022/
# Saved article link: https://publicdomainreview.org/blog/2022/12/top-10-most-read-pieces-from-2022/
# Saved article link: https://publicdomainreview.org/blog/2021/11/last-order-dates-for-christmas-2021/
# Saved article link: https://publicdomainreview.org/blog/2023/11/54-new-prints-and-now-free-shipping!/
# Saved article link: https://publicdomainreview.org/blog/2019/12/the-public-domain-reviews-end-of-year-fundraiser-is-launched/
# Saved article link: https://publicdomainreview.org/blog/2020/06/black-lives-matter/
# Saved article link: https://publicdomainreview.org/blog/2021/11/new-prints-nov-21/
# Saved article link: https://publicdomainreview.org/blog/2022/04/5-million-book-illustrations-deleted-from-flickr/
# Saved article link: https://publicdomainreview.org/blog/2023/12/top-10-most-read-pieces-from-2023/
# Saved article link: https://publicdomainreview.org/blog/2022/06/creative-review-interview/
# Saved article link: https://publicdomainreview.org/blog/2021/04/affinities-a-book-of-images/
# Saved article link: https://publicdomainreview.org/blog/2020/06/launch-of-mid-year-fundraiser/
# Saved article link: https://publicdomainreview.org/blog/2020/03/coronavirus-update/
# Saved article link: https://publicdomainreview.org/blog/2021/12/launch-of-end-of-year-fundraiser-2021/
# Saved article link: https://publicdomainreview.org/blog/2020/11/new-batch-of-prints-and-introducing-themed-sets/
# Saved article link: https://publicdomainreview.org/blog/2020/12/launch-of-end-of-year-fundraiser/
# Saved article link: https://publicdomainreview.org/blog/2024/06/launch-of-mid-year-fundraiser-june-24/
# Saved article link: https://publicdomainreview.org/blog/2021/06/launch-of-mid-year-fundraiser-june-21/
# Saved article link: https://publicdomainreview.org/blog/2023/11/launch-of-end-of-year-fundraiser-2023/
# Saved article link: https://publicdomainreview.org/blog/2021/12/top-10-most-read-pieces-from-2021/
# Saved article link: https://publicdomainreview.org/blog/2020/01/public-domain-in-2020/
# Saved article link: https://publicdomainreview.org/blog/2021/05/a-deeper-dive-into-affinities/
# Saved article link: https://publicdomainreview.org/blog/2022/12/introducing-the-pdr-index/
# Saved article link: https://publicdomainreview.org/blog/2019/11/welcome-to-our-shiny-new-website/
# Saved article link: https://publicdomainreview.org/blog/2020/02/interview-with-pdr-editor-on-nightingale/
# Saved article link: https://publicdomainreview.org/blog/2020/12/top-10-most-read-pieces-of-2020/
# Saved article link: https://publicdomainreview.org/blog/2021/11/tls-review/
# Saved article link: https://publicdomainreview.org/blog/2020/05/free-colouring-book-2/
# Saved article link: https://publicdomainreview.org/blog/2021/12/new-public-domain-countdown-calendar/
# Saved article link: https://publicdomainreview.org/blog/2021/01/celebrating-a-decade-of-the-public-domain-review/
# Saved article link: https://publicdomainreview.org/blog/2020/11/last-order-dates-for-christmas-2020/
# Saved article link: https://publicdomainreview.org/blog/2022/11/launch-of-end-of-year-fundraiser-2022/
# Saved article link: https://publicdomainreview.org/blog/2023/10/sources-and-rights-labelling-overhaul/
# Saved article link: https://publicdomainreview.org/blog/2023/11/last-order-dates-for-christmas-2023/
# Saved article link: https://publicdomainreview.org/blog/2023/01/public-domain-day-2023/
# Saved article link: https://publicdomainreview.org/blog/2020/05/next-postcard-theme-touch/
# Processing: https://publicdomainreview.org/support/
# Saved article link: https://publicdomainreview.org/support/friends
# Saved article link: https://publicdomainreview.org/shop
# Saved article link: https://publicdomainreview.org/support/become-a-friend/
# Saved article link: https://publicdomainreview.org/postcards
# Saved article link: https://publicdomainreview.org/shop/pdr-press-books
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints
# Saved article link: https://publicdomainreview.org/postcards/
# Saved article link: https://publicdomainreview.org/support/donate/
# Processing: https://publicdomainreview.org/collection/eluard-ernst-les-malheurs-des-immortels/
# Saved article link: https://publicdomainreview.org/collections/all/type/fiction/
# Saved article link: https://publicdomainreview.org/tags/collage/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/
# Saved article link: https://publicdomainreview.org/collections/all/epoch/20th-century/
# Saved article link: https://publicdomainreview.org/collections/all/genre/art-design-and-picturebooks/
# Saved article link: https://publicdomainreview.org/tags/surrealism/
# Saved article link: https://publicdomainreview.org/collections/all/genre/poetry/
# Saved article link: https://publicdomainreview.org/contributor/daisy-sainsbury/
# Processing: https://publicdomainreview.org/essay/scenes-of-reading-on-the-early-portrait-postcard/
# Saved article link: https://publicdomainreview.org/tags/group-portraits/
# Saved article link: https://publicdomainreview.org/tags/postcards/
# Saved article link: https://publicdomainreview.org/tags/reading/
# Saved article link: https://publicdomainreview.org/tags/portraiture/
# Saved article link: https://publicdomainreview.org/tags/photography/
# Saved article link: https://publicdomainreview.org/tags/books/
# Processing: https://publicdomainreview.org/contact/
# Saved article link: https://publicdomainreview.org/contributors/
# Processing: https://publicdomainreview.org/collection/principles-of-light-and-color/
# Saved article link: https://publicdomainreview.org/tags/psychic-phenomena/
# Saved article link: https://publicdomainreview.org/contributor/hunter-dukes/
# Saved article link: https://publicdomainreview.org/collections/all/epoch/19th-century/
# Saved article link: https://publicdomainreview.org/tags/ether/
# Saved article link: https://publicdomainreview.org/tags/color/
# Saved article link: https://publicdomainreview.org/collections/all/type/non-fiction/
# Saved article link: https://publicdomainreview.org/collection/gartside-theory-of-colours/
# Saved article link: https://publicdomainreview.org/collections/all/genre/science/
# Saved article link: https://publicdomainreview.org/collection/baraduc-soul/
# Saved article link: https://publicdomainreview.org/collections/source/smithsonian-libraries/
# Saved article link: https://publicdomainreview.org/collection/the-influence-of-the-blue-ray-of-the-sunlight-and-of-the-blue-color-of-the-sky-1877/
# Saved article link: https://publicdomainreview.org/collection/munsell-atlas/
# Saved article link: https://publicdomainreview.org/collection/colour-analysis-charts-by-emily-noyes-vanderpoel-1902/
# Saved article link: https://publicdomainreview.org/tags/chromotherapy/
# Processing: https://publicdomainreview.org/returns-policy/
# Processing: https://publicdomainreview.org/essays/category/art-and-illustration/
# Saved article link: https://publicdomainreview.org/essays/category/poetry/
# Saved article link: https://publicdomainreview.org/essay/picturing-scent/
# Saved article link: https://publicdomainreview.org/essay/liquid-bewitchment/
# Saved article link: https://publicdomainreview.org/essay/little-boney/
# Saved article link: https://publicdomainreview.org/essay/images-from-the-collective-unconscious/
# Saved article link: https://publicdomainreview.org/essay/in-search-of-true-color/
# Saved article link: https://publicdomainreview.org/essays/category/religion-myth-and-legend/
# Saved article link: https://publicdomainreview.org/essay/cliche-verre-and-friendship-in-19th-century-france/
# Saved article link: https://publicdomainreview.org/essay/prousts-pinks/
# Saved article link: https://publicdomainreview.org/essays/category/art-and-illustration/1/
# Saved article link: https://publicdomainreview.org/essay/pseudo-boccaccio-yiddish-pulp-fiction-and-the-man-who-ripped-off-joyce/
# Saved article link: https://publicdomainreview.org/essay/polyhedral-perspective/
# Saved article link: https://publicdomainreview.org/essay/of-angel-and-puppet/
# Saved article link: https://publicdomainreview.org/essay/sanborn-fire-insurance-maps/
# Saved article link: https://publicdomainreview.org/essay/love-and-longing-in-the-seaweed-album/
# Saved article link: https://publicdomainreview.org/essays/category/art-and-illustration/3/
# Saved article link: https://publicdomainreview.org/essays/category/literature/
# Saved article link: https://publicdomainreview.org/essays/category/art-and-illustration/5/
# Saved article link: https://publicdomainreview.org/essays/category/science-and-medicine/
# Saved article link: https://publicdomainreview.org/essays/category/art-and-illustration/4/
# Saved article link: https://publicdomainreview.org/essays/category/performance/
# Saved article link: https://publicdomainreview.org/essay/anna-atkins-cyanotypes/
# Saved article link: https://publicdomainreview.org/essay/documenting-drugs/
# Saved article link: https://publicdomainreview.org/essays/category/philosophy-and-ideas/
# Saved article link: https://publicdomainreview.org/essay/handy-mnemonics/
# Saved article link: https://publicdomainreview.org/essay/a-paper-archaeology/
# Saved article link: https://publicdomainreview.org/essays/category/art-and-illustration/2/
# Saved article link: https://publicdomainreview.org/essay/the-substantiality-of-spirit/
# Saved article link: https://publicdomainreview.org/essay/travelling-tales/
# Saved article link: https://publicdomainreview.org/essay/hypnerotomachia-poliphili-and-the-architecture-of-dreams/
# Saved article link: https://publicdomainreview.org/essay/petrified-waters/
# Saved article link: https://publicdomainreview.org/essay/illusory-wealth/
# Saved article link: https://publicdomainreview.org/essays/category/books/
# Saved article link: https://publicdomainreview.org/essays/category/music/
# Saved article link: https://publicdomainreview.org/essay/black-squares-before-malevich/
# Processing: https://publicdomainreview.org/about/
# Saved article link: https://publicdomainreview.org/collection/w-e-b-du-bois-hand-drawn-infographics-of-african-american-life-1900/
# Saved article link: https://publicdomainreview.org/collection/tlingit-myths-and-texts-1909/
# Saved article link: https://publicdomainreview.org/essay/for-the-sake-of-the-prospect-experiencing-the-world-from-above-in-the-late-18th-century/
# Saved article link: https://publicdomainreview.org/essay/some-remarks-on-the-legacy-of-madame-francine-descartes/
# Saved article link: https://publicdomainreview.org/collections/source/rijksmuseum
# Saved article link: https://publicdomainreview.org/essay/petrarchs-plague/
# Saved article link: https://publicdomainreview.org/essay/an-unlikely-lunch-when-maupassant-met-swinburne/
# Saved article link: https://publicdomainreview.org/essay/remembering-roy-gold-who-was-not-excessively-interested-in-books/
# Saved article link: https://publicdomainreview.org/about/testimonials/
# Saved article link: https://publicdomainreview.org/collection/erbario-15th-century-herbal/
# Saved article link: https://publicdomainreview.org/collections/source/the-getty
# Saved article link: https://publicdomainreview.org/essay/the-sound-and-the-story-exploring-the-world-of-paradise-lost/
# Saved article link: https://publicdomainreview.org/collections/source/the-national-archives
# Saved article link: https://publicdomainreview.org/collections/source/national-library-of-medicine
# Saved article link: https://publicdomainreview.org/collections/source/british-library
# Saved article link: https://publicdomainreview.org/essay/o-uommibatto-how-the-pre-raphaelites-became-obsessed-with-the-wombat/
# Processing: https://publicdomainreview.org/reusing-material/
# Processing: https://publicdomainreview.org/collections/all/theme/travel-and-exploration/
# Saved article link: https://publicdomainreview.org/collections/all/theme/fashion/
# Saved article link: https://publicdomainreview.org/collection/weird-islands/
# Saved article link: https://publicdomainreview.org/collection/nooks-and-corners-of-old-new-york/
# Saved article link: https://publicdomainreview.org/collections/all/theme/humour-and-satire/
# Saved article link: https://publicdomainreview.org/collection/kessel-four-parts-of-the-world/
# Saved article link: https://publicdomainreview.org/collection/carroll-illustrations-for-alice-undergound/
# Saved article link: https://publicdomainreview.org/collection/the-tragedy-of-the-seas-1841/
# Saved article link: https://publicdomainreview.org/collections/all/theme/landscapes/
# Saved article link: https://publicdomainreview.org/collection/shores-of-the-polar-sea/
# Saved article link: https://publicdomainreview.org/collection/merian-metamorphosis/
# Saved article link: https://publicdomainreview.org/collection/dore-new-zealander/
# Saved article link: https://publicdomainreview.org/collection/w-w-denslow-illustrations-wonderful-wizard-of-oz-1900/
# Saved article link: https://publicdomainreview.org/collection/sodomy-punished/
# Saved article link: https://publicdomainreview.org/collections/all/theme/love-and-lust/
# Saved article link: https://publicdomainreview.org/collections/all/theme/sport-and-exercise/
# Saved article link: https://publicdomainreview.org/collections/all/theme/travel-and-exploration/1/
# Saved article link: https://publicdomainreview.org/collections/all/
# Saved article link: https://publicdomainreview.org/collection/through-the-first-antarctic-night-1900/
# Saved article link: https://publicdomainreview.org/collection/man-and-his-desire/
# Saved article link: https://publicdomainreview.org/collections/all/theme/death/
# Saved article link: https://publicdomainreview.org/collection/etidorhpa/
# Saved article link: https://publicdomainreview.org/collections/all/theme/architecture/
# Saved article link: https://publicdomainreview.org/collections/audio/
# Saved article link: https://publicdomainreview.org/collection/recueil-de-la-diversite-des-habits/
# Saved article link: https://publicdomainreview.org/collection/mont-blanc-ascent/
# Saved article link: https://publicdomainreview.org/collections/all/theme/natural-world/
# Saved article link: https://publicdomainreview.org/collections/film/
# Saved article link: https://publicdomainreview.org/collections/all/theme/stories/
# Saved article link: https://publicdomainreview.org/collection/paterson-s-roads-1826-edition/
# Saved article link: https://publicdomainreview.org/collections/all/theme/travel-and-exploration/2/
# Saved article link: https://publicdomainreview.org/collection/dorothy-wordsworths-journal-of-a-few-months-residence-in-portugal-1847/
# Saved article link: https://publicdomainreview.org/collection/the-life-and-adventures-of-peter-wilkins-a-cornish-man-1750/
# Saved article link: https://publicdomainreview.org/collections/all/theme/maps/
# Saved article link: https://publicdomainreview.org/collection/despinque-anglicus-illuminations/
# Saved article link: https://publicdomainreview.org/collection/rabot-photographs-of-the-arctic/
# Saved article link: https://publicdomainreview.org/collections/all/theme/the-future/
# Saved article link: https://publicdomainreview.org/collection/junghuhn-java-album/
# Saved article link: https://publicdomainreview.org/collection/orchid-hunter/
# Saved article link: https://publicdomainreview.org/collection/gay-trivia/
# Processing: https://publicdomainreview.org/collections/all/theme/science-and-medicine/
# Saved article link: https://publicdomainreview.org/collections/all/theme/ghosts-and-occult/
# Saved article link: https://publicdomainreview.org/collection/microscopic-delights/
# Saved article link: https://publicdomainreview.org/collection/moseley-coffee/
# Saved article link: https://publicdomainreview.org/collection/gilded-gallows-of-georg-honauer/
# Saved article link: https://publicdomainreview.org/collection/verany-cephalopods/
# Saved article link: https://publicdomainreview.org/collection/phantom-flowers/
# Saved article link: https://publicdomainreview.org/collections/all/theme/science-and-medicine/1/
# Saved article link: https://publicdomainreview.org/collections/all/theme/work/
# Saved article link: https://publicdomainreview.org/collection/body-as-house-diagram/
# Saved article link: https://publicdomainreview.org/collections/all/theme/science-and-medicine/7/
# Saved article link: https://publicdomainreview.org/collection/eakins-horse-leg/
# Saved article link: https://publicdomainreview.org/collections/all/theme/astronomy-and-space/
# Saved article link: https://publicdomainreview.org/collections/all/theme/science-and-medicine/5/
# Saved article link: https://publicdomainreview.org/collection/dentologia/
# Saved article link: https://publicdomainreview.org/collections/all/theme/science-and-medicine/4/
# Saved article link: https://publicdomainreview.org/collection/cornish-waves/
# Saved article link: https://publicdomainreview.org/collections/all/theme/science-and-medicine/3/
# Saved article link: https://publicdomainreview.org/collection/yaggy-geographical-maps/
# Saved article link: https://publicdomainreview.org/collection/kedzie-shadows/
# Saved article link: https://publicdomainreview.org/collection/fixed-stars/
# Saved article link: https://publicdomainreview.org/collection/visualising-bubbles/
# Saved article link: https://publicdomainreview.org/collection/book-of-monsters/
# Saved article link: https://publicdomainreview.org/collection/synaesthesia-diagrams-1883/
# Saved article link: https://publicdomainreview.org/collection/dr-berkeleys-discovery/
# Saved article link: https://publicdomainreview.org/collections/all/theme/science-and-medicine/2/
# Saved article link: https://publicdomainreview.org/collection/blights-of-the-bookish/
# Saved article link: https://publicdomainreview.org/collection/raman-sea/
# Saved article link: https://publicdomainreview.org/collections/all/theme/drugs/
# Saved article link: https://publicdomainreview.org/collection/occult-chemistry/
# Saved article link: https://publicdomainreview.org/collections/all/theme/science-and-medicine/6/
# Saved article link: https://publicdomainreview.org/collection/concealing-coloration/
# Saved article link: https://publicdomainreview.org/collections/all/theme/crime-and-law/
# Processing: https://publicdomainreview.org/explore/
# Saved article link: https://publicdomainreview.org/tags/
# Saved article link: https://publicdomainreview.org/tags/occult/
# Saved article link: https://publicdomainreview.org/tags/edison/
# Saved article link: https://publicdomainreview.org/tags/language/
# Saved article link: https://publicdomainreview.org/tags/christmas/
# Saved article link: https://publicdomainreview.org/tags/fairytales/
# Saved article link: https://publicdomainreview.org/collections/all/epoch/18th-century/
# Saved article link: https://publicdomainreview.org/tags/technology/
# Saved article link: https://publicdomainreview.org/tags/japan/
# Saved article link: https://publicdomainreview.org/tags/folklore/
# Saved article link: https://publicdomainreview.org/tags/black-history/
# Saved article link: https://publicdomainreview.org/tags/politics/
# Saved article link: https://publicdomainreview.org/tags/fashion/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/natural-history/
# Saved article link: https://publicdomainreview.org/collections/all/theme/geometry-and-diagrams/
# Saved article link: https://publicdomainreview.org/tags/cartography/
# Saved article link: https://publicdomainreview.org/collections/source/national-library-of-medicine/
# Saved article link: https://publicdomainreview.org/tags/education/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/language-and-communication/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/books/
# Saved article link: https://publicdomainreview.org/tags/future-history/
# Saved article link: https://publicdomainreview.org/tags/moon/
# Saved article link: https://publicdomainreview.org/tags/colour/
# Saved article link: https://publicdomainreview.org/collections/source/library-of-congress/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/photography/
# Saved article link: https://publicdomainreview.org/tags/gardens/
# Saved article link: https://publicdomainreview.org/tags/religion/
# Saved article link: https://publicdomainreview.org/tags/astrology/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/science-fiction-and-future-visions/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/illustration/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/design/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/strange-histories/
# Saved article link: https://publicdomainreview.org/tags/folktales/
# Saved article link: https://publicdomainreview.org/tags/animation/
# Saved article link: https://publicdomainreview.org/tags/anatomy/
# Saved article link: https://publicdomainreview.org/tags/astronomy/
# Saved article link: https://publicdomainreview.org/tags/design/
# Saved article link: https://publicdomainreview.org/tags/illustration/
# Saved article link: https://publicdomainreview.org/tags/music/
# Saved article link: https://publicdomainreview.org/tags/caricature/
# Saved article link: https://publicdomainreview.org/tags/early-photography/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/audio/
# Saved article link: https://publicdomainreview.org/tags/spiritualism/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/folk-and-fairytales/
# Saved article link: https://publicdomainreview.org/tags/animals/
# Saved article link: https://publicdomainreview.org/tags/satire/
# Saved article link: https://publicdomainreview.org/tags/disease/
# Saved article link: https://publicdomainreview.org/tags/cats/
# Saved article link: https://publicdomainreview.org/tags/london/
# Saved article link: https://publicdomainreview.org/tags/botany/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/occult/
# Saved article link: https://publicdomainreview.org/tags/travel/
# Saved article link: https://publicdomainreview.org/collections/all/theme/communication/
# Saved article link: https://publicdomainreview.org/tags/colonialism/
# Saved article link: https://publicdomainreview.org/tags/science-fiction/
# Saved article link: https://publicdomainreview.org/tags/plants/
# Saved article link: https://publicdomainreview.org/tags/war/
# Saved article link: https://publicdomainreview.org/tags/sex/
# Saved article link: https://publicdomainreview.org/tags/first-world-war/
# Saved article link: https://publicdomainreview.org/tags/diary/
# Saved article link: https://publicdomainreview.org/tags/racism/
# Saved article link: https://publicdomainreview.org/collections/all/theme/emotion-and-expression/
# Saved article link: https://publicdomainreview.org/tags/alphabet/
# Saved article link: https://publicdomainreview.org/tags/dreams/
# Saved article link: https://publicdomainreview.org/tags/magic/
# Saved article link: https://publicdomainreview.org/tags/sea/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/film/
# Saved article link: https://publicdomainreview.org/tags/poetry/
# Saved article link: https://publicdomainreview.org/collections/all/theme/technology/
# Saved article link: https://publicdomainreview.org/tags/birds/
# Saved article link: https://publicdomainreview.org/collections/all/epoch/17th-century/
# Saved article link: https://publicdomainreview.org/collections/source/the-metropolitan-museum/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/images/
# Saved article link: https://publicdomainreview.org/tags/medicine/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/celestial/
# Saved article link: https://publicdomainreview.org/tags/art/
# Saved article link: https://publicdomainreview.org/tags/electricity/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/maps/
# Saved article link: https://publicdomainreview.org/tags/architecture/
# Saved article link: https://publicdomainreview.org/tags/geometry/
# Saved article link: https://publicdomainreview.org/collections/all/epoch/pre-16th-century/
# Saved article link: https://publicdomainreview.org/tags/ghosts/
# Saved article link: https://publicdomainreview.org/tags/theatre/
# Saved article link: https://publicdomainreview.org/tags/flowers/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/weird-theories/
# Saved article link: https://publicdomainreview.org/collections/all/epoch/16th-century/
# Saved article link: https://publicdomainreview.org/tags/fairy-tales/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/science/
# Saved article link: https://publicdomainreview.org/tags/maps/
# Saved article link: https://publicdomainreview.org/tags/drugs/
# Saved article link: https://publicdomainreview.org/tags/christianity/
# Saved article link: https://publicdomainreview.org/tags/painting/
# Saved article link: https://publicdomainreview.org/collections/source/wellcome-collection/
# Saved article link: https://publicdomainreview.org/best-of-the-pdr/essays/
# Saved article link: https://publicdomainreview.org/collections/all/theme/war/
# Saved article link: https://publicdomainreview.org/tags/slavery/
# Saved article link: https://publicdomainreview.org/tags/retrofuture/
# Saved article link: https://publicdomainreview.org/tags/victorian/
# Saved article link: https://publicdomainreview.org/tags/death/
# Saved article link: https://publicdomainreview.org/tags/france/
# Saved article link: https://publicdomainreview.org/collections/all/theme/wisdom/
# Saved article link: https://publicdomainreview.org/tags/fish/
# Saved article link: https://publicdomainreview.org/tags/opera/
# Saved article link: https://publicdomainreview.org/pd-remix/
# Processing: https://publicdomainreview.org/essays/category/photography/
# Saved article link: https://publicdomainreview.org/essay/photographing-the-dark-nadars-descent-into-the-paris-catacombs/
# Saved article link: https://publicdomainreview.org/essay/the-serious-and-the-smirk-the-smile-in-portraiture/
# Saved article link: https://publicdomainreview.org/essay/remembering-scott/
# Saved article link: https://publicdomainreview.org/essay/yvette-borup-andrews-photographing-central-asia/
# Saved article link: https://publicdomainreview.org/essay/julia-margaret-cameron-in-ceylon-idylls-of-freshwater-vs-idylls-of-rathoongodde/
# Saved article link: https://publicdomainreview.org/essay/neanderthals-in-3d-lhomme-de-la-chapelle/
# Saved article link: https://publicdomainreview.org/essay/the-kept-and-the-killed/
# Saved article link: https://publicdomainreview.org/essay/through-the-cheval-glass/
# Saved article link: https://publicdomainreview.org/essay/the-snowflake-man-of-vermont/
# Saved article link: https://publicdomainreview.org/essay/sir-arthur-and-the-fairies/
# Saved article link: https://publicdomainreview.org/essay/stuffed-ox-dummy-tree-artificial-rock-deception-in-the-work-of-richard-and-cherry-kearton/
# Saved article link: https://publicdomainreview.org/essay/the-naturalist-and-the-neurologist-on-charles-darwin-and-james-crichton-browne/
# Saved article link: https://publicdomainreview.org/essay/the-secret-history-of-holywell-street-home-to-victorian-london-s-dirty-book-trade/
# Processing: https://publicdomainreview.org/essay/henri-rochefort-and-the-origins-of-french-populism/
# Saved article link: https://publicdomainreview.org/tags/journalism/
# Saved article link: https://publicdomainreview.org/tags/censorship/
# Saved article link: https://publicdomainreview.org/essay/laughter-in-the-time-of-cholera/
# Saved article link: https://publicdomainreview.org/tags/vaudeville/
# Processing: https://publicdomainreview.org/collection/briefe-and-true-report-de-bry-engravings/
# Saved article link: https://publicdomainreview.org/tags/native-americans/
# Saved article link: https://publicdomainreview.org/collections/all/style/engraving/
# Saved article link: https://publicdomainreview.org/tags/british-america/
# Saved article link: https://publicdomainreview.org/collection/a-young-daughter-of-the-picts-ca-1585/
# Saved article link: https://publicdomainreview.org/tags/romans/
# Saved article link: https://publicdomainreview.org/tags/tattoo/
# Saved article link: https://publicdomainreview.org/tags/colonial-america/
# Saved article link: https://publicdomainreview.org/essay/painting-the-new-world/
# Saved article link: https://publicdomainreview.org/collections/source/harvard-university/
# Processing: https://publicdomainreview.org/collections/
# Saved article link: https://publicdomainreview.org/collection/paul-fejos-lonesome/
# Saved article link: https://publicdomainreview.org/collection/wild-flowers-of-palestine/
# Saved article link: https://publicdomainreview.org/collections/all/5/
# Saved article link: https://publicdomainreview.org/collection/lyon-woven-prayer-book/
# Saved article link: https://publicdomainreview.org/collection/nos-invisibles/
# Saved article link: https://publicdomainreview.org/collection/chinese-arabesques/
# Saved article link: https://publicdomainreview.org/collection/hartlieb-book-of-herbs/
# Saved article link: https://publicdomainreview.org/collections/all/3/
# Saved article link: https://publicdomainreview.org/collections/all/2/
# Saved article link: https://publicdomainreview.org/collection/the-toll-of-the-sea/
# Saved article link: https://publicdomainreview.org/collection/the-learned-maid/
# Saved article link: https://publicdomainreview.org/collection/the-plague-of-lust/
# Saved article link: https://publicdomainreview.org/collections/all/4/
# Saved article link: https://publicdomainreview.org/collection/diagramming-sentences-in-the-19th-century/
# Saved article link: https://publicdomainreview.org/collections/all/49/
# Saved article link: https://publicdomainreview.org/collection/antiquities-of-mexico/
# Saved article link: https://publicdomainreview.org/collection/eye-miniatures/
# Saved article link: https://publicdomainreview.org/collection/ruckenfigur/
# Saved article link: https://publicdomainreview.org/collections/all/1/
# Processing: https://publicdomainreview.org/collections/all/theme/colonialism-and-the-'other'/
# Saved article link: https://publicdomainreview.org/collection/utsuro-bune/
# Saved article link: https://publicdomainreview.org/collection/celestial-phenomenon-over-nuremberg-april-14th-1561/
# Saved article link: https://publicdomainreview.org/collection/hans-prinzhorn-s-artistry-of-the-mentally-ill-1922/
# Saved article link: https://publicdomainreview.org/collection/edward-curtis-photographs-of-kwakwaka-wakw-ceremonial-dress-and-masks-ca-1914/
# Saved article link: https://publicdomainreview.org/collection/the-life-and-adventures-of-james-f-o-connell-the-tattooed-man-1845/
# Saved article link: https://publicdomainreview.org/collection/le-voyage-dans-la-lune-1902/
# Saved article link: https://publicdomainreview.org/collection/an-account-of-a-chinese-cabinet-1753/
# Saved article link: https://publicdomainreview.org/collection/comparative-physiognomy-or-resemblances-between-men-and-animals-1852/
# Saved article link: https://publicdomainreview.org/collections/all/theme/colonialism-and-the-'other'/2/
# Saved article link: https://publicdomainreview.org/collection/letters-to-my-sister-of-our-experiences-on-our-first-trip-to-europe-1913/
# Saved article link: https://publicdomainreview.org/collection/texts-in-mathias-enard-s-compass/
# Saved article link: https://publicdomainreview.org/collection/extracts-from-the-endeavour-journal-of-joseph-banks-1769/
# Saved article link: https://publicdomainreview.org/collection/conversations-with-lord-byron-1824/
# Saved article link: https://publicdomainreview.org/collection/recordings-of-pygmy-music-from-the-1946-ogooue-congo-mission/
# Saved article link: https://publicdomainreview.org/collections/all/theme/colonialism-and-the-'other'/1/
# Saved article link: https://publicdomainreview.org/collection/japanese-prints-of-western-inventors-artists-and-scholars-1873/
# Saved article link: https://publicdomainreview.org/collection/japanese-depictions-of-north-americans-1860s/
# Saved article link: https://publicdomainreview.org/collection/from-india-to-the-planet-mars-1900/
# Saved article link: https://publicdomainreview.org/collection/how-i-killed-the-tiger-1902/
# Saved article link: https://publicdomainreview.org/collection/sketches-in-bedlam-1823/
# Saved article link: https://publicdomainreview.org/collection/kaspar-hauser-art/
# Processing: https://publicdomainreview.org/shop/
# Saved article link: https://publicdomainreview.org/shop/t-shirts-mugs/
# Saved article link: https://publicdomainreview.org/product/null/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/new/
# Processing: https://publicdomainreview.org/about/submissions/
# Saved article link: https://publicdomainreview.org/essay/grandville-visions-and-dreams/
# Saved article link: https://publicdomainreview.org/essay/out-of-their-love-they-made-it-a-visual-history-of-buraq/
# Saved article link: https://publicdomainreview.org/essay/frolicsome-engines-the-long-prehistory-of-artificial-intelligence/
# Saved article link: https://publicdomainreview.org/essay/the-krakatoa-sunsets/
# Processing: https://publicdomainreview.org/collections/books/
# Saved article link: https://publicdomainreview.org/collection/christmas-garland/
# Saved article link: https://publicdomainreview.org/collections/books/5/
# Saved article link: https://publicdomainreview.org/collection/edith-wharton-italian-villas/
# Saved article link: https://publicdomainreview.org/collection/le-petit-journal-des-refusees/
# Saved article link: https://publicdomainreview.org/collections/books/1/
# Saved article link: https://publicdomainreview.org/collections/books/17/
# Saved article link: https://publicdomainreview.org/collection/capital-and-labor/
# Saved article link: https://publicdomainreview.org/collection/frankenstein-monster-reading-list/
# Saved article link: https://publicdomainreview.org/collection/galateo/
# Saved article link: https://publicdomainreview.org/collections/books/3/
# Saved article link: https://publicdomainreview.org/collection/tom-seidmann-freud-hare-tales/
# Saved article link: https://publicdomainreview.org/collection/the-book-of-halloween/
# Saved article link: https://publicdomainreview.org/collection/my-lady-nicotine/
# Saved article link: https://publicdomainreview.org/collections/books/4/
# Saved article link: https://publicdomainreview.org/collection/millions-of-cats/
# Saved article link: https://publicdomainreview.org/collection/books-fatal-to-their-authors/
# Saved article link: https://publicdomainreview.org/collections/books/2/
# Processing: https://publicdomainreview.org/support/friends/
# Saved article link: https://publicdomainreview.org/support/friends/bit.ly/kellymchugh
# Saved article link: https://publicdomainreview.org/support/friends/Lally Gartel
# Saved article link: https://publicdomainreview.org/support/friends/Kevin William Leslie
# Saved article link: https://publicdomainreview.org/support/friends/
# Saved article link: https://publicdomainreview.org/support/friends/ratherearnest.com
# Processing: https://publicdomainreview.org/shop/pdr-press-books/
# Saved article link: https://publicdomainreview.org/shop/affinities/
# Saved article link: https://publicdomainreview.org/product/the-public-domain-review-selected-essays-vol-iii/
# Saved article link: https://publicdomainreview.org/product/the-public-domain-review-selected-essays-vol-vii/
# Saved article link: https://publicdomainreview.org/product/the-public-domain-review-selected-essays-vol-vi/
# Saved article link: https://publicdomainreview.org/product/the-public-domain-review-selected-essays-vol-iv/
# Saved article link: https://publicdomainreview.org/product/oh-excellent-air-bag-under-the-influence-of-nitrous-oxide-1799-1920/
# Saved article link: https://publicdomainreview.org/product/the-public-domain-review-selected-essays-vol-i/
# Saved article link: https://publicdomainreview.org/product/lucians-dialogues-of-the-gods/
# Saved article link: https://publicdomainreview.org/product/the-public-domain-review-selected-essays-vol-v/
# Saved article link: https://publicdomainreview.org/product/the-public-domain-review-selected-essays-vol-ii/
# Processing: https://publicdomainreview.org/collections/all/theme/people/
# Saved article link: https://publicdomainreview.org/collection/hainhofer-stammbuch/
# Saved article link: https://publicdomainreview.org/collection/cummins-indian-congress/
# Saved article link: https://publicdomainreview.org/collection/dexter-pickle/
# Saved article link: https://publicdomainreview.org/collection/chester-hardings-my-egotistigraphy-1866/
# Saved article link: https://publicdomainreview.org/collections/all/theme/people/3/
# Saved article link: https://publicdomainreview.org/collection/kusakabe-kimbei-s-photographs-of-late-19th-century-japan/
# Saved article link: https://publicdomainreview.org/collection/photographs-of-palestinian-life/
# Saved article link: https://publicdomainreview.org/collection/daniel-murray-preliminary-list/
# Saved article link: https://publicdomainreview.org/collection/the-wise-boys-or-the-entertaining-histories-of-fred-forethought-matt-merrythought-luke-lovebook-and-ben-bee-ca-1842/
# Saved article link: https://publicdomainreview.org/collection/the-living-photographs-of-mole-and-thomas/
# Saved article link: https://publicdomainreview.org/collection/adeline-harris-sears-autographs-quilt-1856-ca-1863/
# Saved article link: https://publicdomainreview.org/collection/sadakichi-hartmann-conversations-with-walt-whitman/
# Saved article link: https://publicdomainreview.org/collections/all/theme/people/5/
# Saved article link: https://publicdomainreview.org/collection/the-human-pyramids-of-juste-de-juste-ca-1540/
# Saved article link: https://publicdomainreview.org/collections/all/theme/people/1/
# Saved article link: https://publicdomainreview.org/collection/augustus-janssons-queen-city-ink-adverts-1903-1907/
# Saved article link: https://publicdomainreview.org/collection/babb-photographs/
# Saved article link: https://publicdomainreview.org/collection/marcus-selmer-s-photographs-of-19th-century-norwegians/
# Saved article link: https://publicdomainreview.org/collections/all/theme/people/4/
# Saved article link: https://publicdomainreview.org/collection/testa-anatomica/
# Saved article link: https://publicdomainreview.org/collections/all/theme/people/2/
# Saved article link: https://publicdomainreview.org/collection/arcimboldo-esque-composite-portraits-of-trades-ca-1800/
# Saved article link: https://publicdomainreview.org/collection/d-a-rovinskiis-collection-of-russian-lubki-18th–19th-century/
# Saved article link: https://publicdomainreview.org/collection/the-confidence-man-1857/
# Saved article link: https://publicdomainreview.org/collection/leave-it-to-psmith-1923/
# Saved article link: https://publicdomainreview.org/collection/john-h-white-documerica/
# Saved article link: https://publicdomainreview.org/collection/the-narrative-of-henry-box-brown-1849/
# Processing: https://publicdomainreview.org/collections/all/theme/politics/
# Saved article link: https://publicdomainreview.org/collection/various-apocalyptic-scenes-from-the-prophetic-messenger-ca-1827-61/
# Saved article link: https://publicdomainreview.org/collection/kollwitz-peasants-war/
# Saved article link: https://publicdomainreview.org/collection/mary-wollstonecrafts-adventures-in-scandinavia/
# Saved article link: https://publicdomainreview.org/collections/all/theme/politics/2/
# Saved article link: https://publicdomainreview.org/collection/why-women-should-not-vote/
# Saved article link: https://publicdomainreview.org/collections/all/theme/politics/3/
# Saved article link: https://publicdomainreview.org/collection/woodrow-wilson-on-democratic-principles-1912/
# Saved article link: https://publicdomainreview.org/collection/bruegel-big-fish-little-fish/
# Saved article link: https://publicdomainreview.org/collection/equality-of-the-sexes/
# Saved article link: https://publicdomainreview.org/collection/march-of-the-intellect/
# Saved article link: https://publicdomainreview.org/collection/autographs-for-freedom-1853/
# Saved article link: https://publicdomainreview.org/collection/frederick-douglass-fourth-july-speech/
# Saved article link: https://publicdomainreview.org/collections/all/theme/politics/1/
# Saved article link: https://publicdomainreview.org/collection/twenty-eight-years-of-co-partnership-at-guise/
# Saved article link: https://publicdomainreview.org/collection/execution-by-guillotine-of-louis-xvi/
# Saved article link: https://publicdomainreview.org/collection/hamann-turner/
# Saved article link: https://publicdomainreview.org/collection/russian-portraits-1921/
# Saved article link: https://publicdomainreview.org/collection/a-true-and-wonderful-narrative/
# Saved article link: https://publicdomainreview.org/collection/fechtbucher/
# Saved article link: https://publicdomainreview.org/collection/the-triumphal-arch-of-emperor-maximilian-i-1515/
# Processing: https://publicdomainreview.org/collection/cardiff-giant/
# Saved article link: https://publicdomainreview.org/tags/giants/
# Saved article link: https://publicdomainreview.org/tags/p-t-barnum/
# Saved article link: https://publicdomainreview.org/tags/hoax/
# Saved article link: https://publicdomainreview.org/tags/sideshow/
# Saved article link: https://publicdomainreview.org/tags/natural-history/
# Saved article link: https://publicdomainreview.org/collections/all/style/photography/
# Processing: https://publicdomainreview.org/terms-and-conditions/
# Processing: https://publicdomainreview.org/collections/all/theme/customs-and-culture/
# Saved article link: https://publicdomainreview.org/collection/wierix-flemish-proverbs/
# Saved article link: https://publicdomainreview.org/collections/all/theme/customs-and-culture/1/
# Saved article link: https://publicdomainreview.org/collection/kumanaki-kage/
# Saved article link: https://publicdomainreview.org/collection/dictionary-of-modern-slang/
# Saved article link: https://publicdomainreview.org/collection/smillie-smithsonian/
# Saved article link: https://publicdomainreview.org/collections/all/theme/customs-and-culture/4/
# Saved article link: https://publicdomainreview.org/collection/mandrakes/
# Saved article link: https://publicdomainreview.org/collection/paper-lantern-catalogue/
# ...
# Processing: https://publicdomainreview.org/shop/fine-art-prints/31/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/30/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/subject/china/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/12/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/11/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/7/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/8/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/9/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/10/
# Processing: https://publicdomainreview.org/further-reading/9/
# Processing: https://publicdomainreview.org/further-reading/10/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/32/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/31/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/8/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/9/most-recent/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/9/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/10/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/21/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/20/
# Processing: https://publicdomainreview.org/collections/all/epoch/20th-century/9/
# Processing: https://publicdomainreview.org/collections/all/epoch/19th-century/12/
# Saved article link: https://publicdomainreview.org/collections/all/epoch/19th-century/11/
# Processing: https://publicdomainreview.org/collections/all/epoch/19th-century/9/
# Saved article link: https://publicdomainreview.org/collections/all/epoch/19th-century/10/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/artist/zacharias-webber-(ii)/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/subject/bow-and-arrow/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/subject/neck/
# Processing: https://publicdomainreview.org/collections/all/41/
# Saved article link: https://publicdomainreview.org/collections/all/40/
# Processing: https://publicdomainreview.org/collections/all/10/
# Saved article link: https://publicdomainreview.org/collections/all/11/
# Processing: https://publicdomainreview.org/collections/images/10/
# Saved article link: https://publicdomainreview.org/collections/images/11/
# Processing: https://publicdomainreview.org/collections/images/13/
# Saved article link: https://publicdomainreview.org/collections/images/12/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/30/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/29/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/11/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/10/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/8/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/9/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/10/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/11/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/31/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/30/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/9/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/10/most-recent/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/10/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/11/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/20/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/19/
# Processing: https://publicdomainreview.org/collections/all/epoch/19th-century/11/
# Processing: https://publicdomainreview.org/collections/all/epoch/19th-century/10/
# Processing: https://publicdomainreview.org/collections/all/40/
# Saved article link: https://publicdomainreview.org/collections/all/39/
# Processing: https://publicdomainreview.org/collections/all/11/
# Saved article link: https://publicdomainreview.org/collections/all/12/
# Processing: https://publicdomainreview.org/collections/images/11/
# Processing: https://publicdomainreview.org/collections/images/12/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/29/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/28/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/10/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/century/19th-century/9/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/11/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/12/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/30/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/29/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/10/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/11/most-recent/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/11/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/12/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/19/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/18/
# Processing: https://publicdomainreview.org/collections/all/39/
# Saved article link: https://publicdomainreview.org/collections/all/38/
# Processing: https://publicdomainreview.org/collections/all/12/
# Saved article link: https://publicdomainreview.org/collections/all/13/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/28/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/27/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/12/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/13/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/29/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/28/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/11/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/12/most-recent/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/12/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/13/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/18/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/17/
# Processing: https://publicdomainreview.org/collections/all/38/
# Saved article link: https://publicdomainreview.org/collections/all/37/
# Processing: https://publicdomainreview.org/collections/all/13/
# Saved article link: https://publicdomainreview.org/collections/all/14/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/27/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/26/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/13/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/14/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/28/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/27/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/12/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/13/most-recent/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/13/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/14/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/17/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/16/
# Processing: https://publicdomainreview.org/collections/all/37/
# Saved article link: https://publicdomainreview.org/collections/all/36/
# Saved article link: https://publicdomainreview.org/collection/class-of-2013/
# Processing: https://publicdomainreview.org/collections/all/14/
# Saved article link: https://publicdomainreview.org/collections/all/15/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/26/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/25/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/14/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/15/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/27/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/26/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/13/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/14/most-recent/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/14/
# Saved article link: https://publicdomainreview.org/collections/source/internet-archive/15/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/16/
# Processing: https://publicdomainreview.org/collections/all/36/
# Saved article link: https://publicdomainreview.org/collections/all/35/
# Processing: https://publicdomainreview.org/collection/class-of-2013/
# Processing: https://publicdomainreview.org/collections/all/15/
# Saved article link: https://publicdomainreview.org/collections/all/16/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/25/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/24/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/15/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/16/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/26/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/25/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/14/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/15/most-recent/
# Processing: https://publicdomainreview.org/collections/source/internet-archive/15/
# Processing: https://publicdomainreview.org/collections/all/35/
# Saved article link: https://publicdomainreview.org/collections/all/34/
# Processing: https://publicdomainreview.org/collections/all/16/
# Saved article link: https://publicdomainreview.org/collections/all/17/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/24/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/23/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/16/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/17/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/25/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/24/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/15/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/16/most-recent/
# Processing: https://publicdomainreview.org/collections/all/34/
# Saved article link: https://publicdomainreview.org/collections/all/33/
# Processing: https://publicdomainreview.org/collections/all/17/
# Saved article link: https://publicdomainreview.org/collections/all/18/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/23/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/22/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/17/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/18/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/24/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/23/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/16/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/17/most-recent/
# Processing: https://publicdomainreview.org/collections/all/33/
# Saved article link: https://publicdomainreview.org/collections/all/32/
# Processing: https://publicdomainreview.org/collections/all/18/
# Saved article link: https://publicdomainreview.org/collections/all/19/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/22/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/21/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/18/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/19/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/23/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/22/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/17/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/18/most-recent/
# Processing: https://publicdomainreview.org/collections/all/32/
# Saved article link: https://publicdomainreview.org/collections/all/31/
# Processing: https://publicdomainreview.org/collections/all/19/
# Saved article link: https://publicdomainreview.org/collections/all/20/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/21/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/20/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/19/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/22/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/21/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/18/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/19/most-recent/
# Processing: https://publicdomainreview.org/collections/all/31/
# Saved article link: https://publicdomainreview.org/collections/all/30/
# Processing: https://publicdomainreview.org/collections/all/20/
# Saved article link: https://publicdomainreview.org/collections/all/21/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/20/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/21/most-recent/
# Saved article link: https://publicdomainreview.org/shop/fine-art-prints/20/most-recent/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/19/most-recent/
# Processing: https://publicdomainreview.org/collections/all/30/
# Saved article link: https://publicdomainreview.org/collections/all/29/
# Processing: https://publicdomainreview.org/collections/all/21/
# Saved article link: https://publicdomainreview.org/collections/all/22/
# Processing: https://publicdomainreview.org/shop/fine-art-prints/20/most-recent/
# Processing: https://publicdomainreview.org/collections/all/29/
# Saved article link: https://publicdomainreview.org/collections/all/28/
# Processing: https://publicdomainreview.org/collections/all/22/
# Saved article link: https://publicdomainreview.org/collections/all/23/
# Processing: https://publicdomainreview.org/collections/all/28/
# Saved article link: https://publicdomainreview.org/collections/all/27/
# Processing: https://publicdomainreview.org/collections/all/23/
# Saved article link: https://publicdomainreview.org/collections/all/24/
# Processing: https://publicdomainreview.org/collections/all/27/
# Saved article link: https://publicdomainreview.org/collections/all/26/
# Processing: https://publicdomainreview.org/collections/all/24/
# Saved article link: https://publicdomainreview.org/collections/all/25/
# Processing: https://publicdomainreview.org/collections/all/26/
# Processing: https://publicdomainreview.org/collections/all/25/
# Crawling complete. Progress saved.

# %% [markdown]
# ### Text Extraction

# %%
import csv
import requests
import os
from bs4 import BeautifulSoup

# File paths
csv_file_path = 'Assignment1/Abhyudaya/Scripts and Data/pdr_article_links.csv'
visited_links_file = 'Assignment1/Abhyudaya/Scripts and Data/PDR_visited_links.txt'
txt_files_directory = 'Assignment1/Abhyudaya/Data/pdrdotorg'

# Ensure the directory exists
if not os.path.exists(txt_files_directory):
    os.makedirs(txt_files_directory)

# Read the links from the CSV file
def get_links(csv_file_path):
    with open(csv_file_path, newline='', encoding='utf-8') as file:
        return [row[0] for row in csv.reader(file) if row]

# Read the visited links from visited_links.txt
def get_visited_links(visited_links_file):
    if os.path.exists(visited_links_file):
        with open(visited_links_file, 'r', encoding='utf-8') as file:
            return set(line.strip() for line in file)
    return set()

# Write the visited link to visited_links.txt
def add_to_visited(link):
    with open(visited_links_file, 'a', encoding='utf-8') as file:
        file.write(link + '\n')

# Fetch content from the link and extract text using BeautifulSoup
def fetch_and_extract_text(link):
    try:
        response = requests.get(link)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all <p> tags on the page
        paragraphs = [p.get_text() for p in soup.find_all('p')]
        if not paragraphs:
            print(f"No <p> tags found in {link}, skipping.")
            return None

        return '\n'.join(paragraphs)  # Combine all paragraphs into a single string
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {link}: {e}")
        return None

# Save content to a txt file in the specified directory
def save_to_file(content, file_number):
    file_path = os.path.join(txt_files_directory, f'pdr_{file_number}.txt')
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(content)

# The main logic to process the links
links = get_links(csv_file_path)
visited_links = get_visited_links(visited_links_file)

for index, link in enumerate(links):
    if link in visited_links:
        print(f"Skipping {link}, already visited.")
        continue

    content = fetch_and_extract_text(link)
    if content:
        save_to_file(content, index + 1)  # Save as pdr_1.txt, pdr_2.txt, etc.
        add_to_visited(link)  # Mark link as visited
        print(f"Saved content from {link} to {txt_files_directory}/pdr_{index + 1}.txt")
